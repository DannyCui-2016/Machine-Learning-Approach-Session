# %%
import numpy as np
import matplotlib.pyplot as plt  # no dot at the end

fig = plt.figure()  # this goes on its own line

# %%
import numpy as np

x = np.linspace(0, 5, 11)  
y = x * 2                  
z = x ** 2

# %%
fig = plt.figure()


ax = fig.add_axes([0, 0, 1, 1])
ax2 = fig.add_axes([.2,.5,.4,.4])

ax.plot(x,z)
ax.set_xlabel('x')
ax.set_ylabel('z')


ax2.plot(x,y)
ax2.set_title('zoom')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
plt.savefig('goo goo ga ga')

# %%
fig,axes  = plt.subplots(1,2)

axes[0].plot(x,y,color = 'blue',ls='--')
axes[1].plot(x,z,color='red',lw=3)

# %%
fig,axes  = plt.subplots(1,2,figsize=(12,2))

axes[0].plot(x,y,color = 'blue',lw=3)
axes[1].plot(x,z,color='red',lw=3,ls='--')
