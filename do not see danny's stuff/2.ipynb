# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
tips = sns.load_dataset('tips')
tips.head()
import numpy as np

# %%
sns.barplot(x='total_bill', y='day', data=tips, estimator=np.std)
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>
