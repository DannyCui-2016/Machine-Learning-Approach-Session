# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1 = pd.read_csv('df1.csv')

# %%
df1.head()
# Out:
#           A         B         C         D
# 0  1.339091 -0.163643 -0.646443  1.041233
# 1 -0.774984  0.137034 -0.882716 -2.253382
# 2 -0.921037 -0.482294 -0.417100  0.478638
# 3 -1.738808 -0.072973  0.056517  0.015085
# 4 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2.csv')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['sepal_length'].hist(bins=30)
plt.xlabel('Sepal Length')
plt.ylabel('Frequency')
plt.title('Histogram of Sepal Length')
plt.show()

# %%
iris[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']].plot.area(alpha=0.4)
plt.title('Area Plot of Iris Features')
plt.xlabel('Index')
plt.ylabel('Value')
plt.show()

# %%
df2.plot.bar()
plt.title('Bar Plot of df2')
plt.xlabel('Index')
plt.ylabel('Values')
plt.show()

# %%
df2.plot.bar(stacked=True, alpha=0.5, colormap='viridis')
# Out:
# <Axes: >

# %%
iris.plot.line(x='sepal_length', y='sepal_width', figsize=(12,6),lw=1)
# Out:
# <Axes: xlabel='sepal_length'>

# %%
iris.plot.scatter(x='sepal_length', y='sepal_width', c='purple', alpha=0.6, s=50)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
iris[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']].plot.box()
# Out:
# <Axes: >

# %%
iris.plot.hexbin(x='sepal_length', y='sepal_width', gridsize=25)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>
