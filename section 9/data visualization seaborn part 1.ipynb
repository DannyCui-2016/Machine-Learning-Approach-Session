# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
import seaborn as sns
tips = sns.load_dataset('tips')

# %%
import matplotlib.pyplot as plt

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips['total_bill'],kde=False,bins=30)
# Out:
# /var/folders/5c/qq0xxrwj4t52gws0b9nfcmv40000gn/T/ipykernel_77477/1274391954.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'],kde=False,bins=30)
# <Axes: xlabel='total_bill'>

# %%
sns.distplot(tips['total_bill'],kde=False,bins=40)
# Out:
# /var/folders/5c/qq0xxrwj4t52gws0b9nfcmv40000gn/T/ipykernel_77477/168061831.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'],kde=False,bins=40)
# <Axes: xlabel='total_bill'>

# %%
sns.distplot(tips['total_bill'],kde=False,bins=100)
# Out:
# /var/folders/5c/qq0xxrwj4t52gws0b9nfcmv40000gn/T/ipykernel_77477/2948379418.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'],kde=False,bins=100)
# <Axes: xlabel='total_bill'>

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex')

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='reg')
plt.savefig('boo')

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='kde')
plt.savefig('ah')

# %%
import matplotlib.pyplot as plt

# %%
sns.pairplot(tips)
plt.savefig('sus')

# %%
sns.pairplot(tips,hue='sex',palette='coolwarm')
import matplotlib.pyplot as plt
plt.savefig('sui')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Example dataset
tips = sns.load_dataset("tips")

# Change palette to "viridis"
sns.pairplot(tips, hue='sex', palette='viridis')

# Save figure
plt.savefig('sui-viridis.png')  # always include file extension
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Example dataset
tips = sns.load_dataset("tips")

# Change palette to "plasma"
sns.pairplot(tips, hue='sex', palette='plasma')

# Save figure
plt.savefig('sui-plasma.png')  # always include file extension
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Example dataset
tips = sns.load_dataset("tips")

# Change palette to "Set2"
sns.pairplot(tips, hue='sex', palette='Set2')

# Save figure
plt.savefig('sui-Set2.png')  # always include file extension
plt.show()
