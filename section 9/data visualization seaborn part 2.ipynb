# %%
import seaborn as sns
# %matplotlib inline
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import seaborn as sns
import numpy as np

tips = sns.load_dataset("tips")

sns.barplot(x="sex", y="total_bill", data=tips, estimator=np.std)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.boxplot(x='day',y='total_bill',data=tips,hue='smoker')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
import matplotlib.pyplot as plt

# %%
sns.violinplot(x='day',y='total_bill',data=tips,palette='rainbow')
plt.savefig('violinplot.png')
# Out:
# /var/folders/5c/qq0xxrwj4t52gws0b9nfcmv40000gn/T/ipykernel_8510/1788623233.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='day',y='total_bill',data=tips,palette='rainbow')

# %%
sns.stripplot(x='day',y='total_bill',data=tips)
plt.savefig('stripplot.png')

# %%
sns.swarmplot(x='day',y='total_bill',data=tips)
plt.savefig('swarmplot.png')

# %%
sns.swarmplot(x='day',y='total_bill',data=tips)
sns.violinplot(x='day',y='total_bill',data=tips,palette='rainbow')
plt.savefig('swarmplot.png')
# Out:
# /var/folders/5c/qq0xxrwj4t52gws0b9nfcmv40000gn/T/ipykernel_8510/3827148377.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='day',y='total_bill',data=tips,palette='rainbow')

# %%
import seaborn as sns

tips = sns.load_dataset("tips")

sns.catplot(x="day", y="total_bill", data=tips, kind="bar")
plt.savefig('catplot.png')
